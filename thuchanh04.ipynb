# %% [markdown]
# <a href="https://colab.research.google.com/github/Huynhngocthanh/shinzerorin/blob/main/thuchanh04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from bs4 import BeautifulSoup
import requests
from urllib.request import urlopen

# %% [markdown]
# 1. Tải 1 url về

# %%
url = "http://vietnamnet.vn/"
soup = BeautifulSoup(url)
print(soup)
# Out:
# <html><body><p>http://vietnamnet.vn/</p></body></html>
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:336: UserWarning: "http://vietnamnet.vn/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %% [markdown]
# 2. Lưu 1 html vào thư mục chỉ định

# %%
file = "url_list" + ".txt"
f = open(file, mode = "w")
f.write('url\n')    #Nhập nội dung file
f.close()
h = "C:\\Users\\ADMIN\\Desktop"+"\\"+file
os.rename(file,h)   #lưu file

# %% [markdown]
# 3. Cách lấy 1 phần tử đầu tiên ra khỏi list và xóa nó khỏi list

# %%
t = ['một','hai','ba','bốn']
print('CHuỗi trước khi edit:',t)
h = t.pop(0)
print('Phần tử đầu tiên:',h)
print('Chuỗi sau khi edit:',t)
# Out:
# CHuỗi trước khi edit: ['một', 'hai', 'ba', 'bốn']
# Phần tử đầu tiên: một
# Chuỗi sau khi edit: ['hai', 'ba', 'bốn']

# %% [markdown]
# 4. Cách lấy các url trong html

# %%
html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
for item in bs.find_all("a"):
    if 'href' in item.attrs:
        print(item.attrs['href'])
# Out:
# /
# https://vietnamnet.vn/vn/thoi-su/dai-hoi-dang-lan-thu-xiii/
# #
# /vn/tin-moi-nong/
# /vn/tin-tuc-24h/
# https://www.facebook.com/vietnamnet.vn
# https://www.youtube.com/vietnamnetofficial
# javascript:void(0)
# javascript:void(0)
# https://id.vietnamnet.vn/Home.html
# javascript:void(0)
# /
# /vn/thoi-su/chinh-tri/
# /vn/talkshow/
# /vn/thoi-su/
# /vn/thoi-su/chong-tham-nhung/
# /vn/thoi-su/quoc-hoi/
# /vn/thoi-su/an-toan-giao-thong/
# /vn/thoi-su/moi-truong/
# /vn/thoi-su/clip-nong/
# /vn/thoi-su/bhxh-bhyt/
# /vn/thoi-su/quoc-phong/
# /vn/kinh-doanh/
# /vn/kinh-doanh/tai-chinh/
# /vn/kinh-doanh/dau-tu/
# /vn/kinh-doanh/thi-truong/
# /vn/kinh-doanh/doanh-nhan/
# /vn/kinh-doanh/tu-van-tai-chinh/
# /vn/kinh-doanh/Amaccao/
# /vn/giai-tri/
# /vn/giai-tri/the-gioi-sao/
# /vn/giai-tri/thoi-trang/
# /vn/giai-tri/nhac/
# /vn/giai-tri/phim/
# /vn/giai-tri/truyen-hinh/
# /vn/giai-tri/sach/
# /vn/giai-tri/di-san-my-thuat-san-khau/
# /vn/the-gioi/
# /vn/the-gioi/binh-luan-quoc-te/
# ...

# %% [markdown]
# 5. Kiểm tra đường link

# %%
# Out:
#   File "<ipython-input-48-9cdd93643439>", line 1
#     for i in BeautifulSoup(html)
#                                 ^
# SyntaxError: invalid syntax
